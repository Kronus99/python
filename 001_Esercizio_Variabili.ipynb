# %% [markdown]
# Esercizio 1
# Dichiarare una variabile "nome" e assegnargli il tuo nome. Mandare a schermo.

# %%
echo "# python" >> README.md
git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/Kronus99/python.git
git push -u origin main

# %%
nome = "Silvio"
print(nome)
type(nome)
# Out:
# Silvio
# str

# %% [markdown]
# Esercizio 2
# Dichiarare una variabile "eta" e assegnargli la tua età. Mandare a schermo.

# %%
eta = 25
print(eta)
type(eta)
# Out:
# 25
# int

# %% [markdown]
# Esercizio 3
# Dichiarare una variabile "pi" e assegnargli il valore di pi greco (3,14159). Mandare a schermo.

# %%
import math
pi = math.pi
print(pi)
type(pi)
# Out:
# 3.141592653589793
# float

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# Esercizio 4
# Creare una variabile "lunghezza" e assegnargli un valore, quindi riassegnare la variabile a 15. Mandare a schermo.

# %%
lunghezza = 10
lunghezza = 15
print(lunghezza)
# Out:
# 15

# %% [markdown]
# **Esercizio 5**
# Creare una variabile "nome_completo" e assegnargli una stringa contenente il tuo nome e cognome. Mandare a schermo

# %%
nome_completo = "Silvio Coppa"
print(nome_completo)
type(nome_completo)
# Out:
# Silvio Coppa
# str

# %%
nome_completo = "Silvio" + " " + "Coppa"
print(nome_completo)
type(nome_completo)
# Out:
# Silvio Coppa
# str

# %%
nome = "Silvio"
cognome = "Coppa"
nome_completo = nome + " " + cognome
print(nome_completo)
type(nome_completo)
# Out:
# Silvio Coppa
# str

# %% [markdown]
# **Esercizio 6**
# Creare una variabile "eta_futura" e assegnargli il valore dell'età che avrai tra 10 anni (utilizzando la variabile età già esistente). Mansare a schermo.

# %%
eta = 25
eta_futura = eta + 10
print(eta_futura)
type(eta_futura)
# Out:
# 35
# int

# %%
eta = input("Inserisci la tua età: ")
eta_futura = int(eta) + 10
print(eta_futura)
type(eta_futura)
# Out:
# Inserisci la tua età: 25
# 35
# int

# %% [markdown]
# **Esercizio 7**
# Creare delle variabili "nome", "cognome" ed "anno_di_nascita" ed assegnargli i valori. Mandare a schermo in un unico print. Sovrascrivere tutte le variabili e rimandare a schermo una seconda volta.

# %%
nome = "Silvio"
cognome = "Coppa"
anno_di_nascita = 1999
print(nome, cognome, anno_di_nascita)
# Out:
# Silvio Coppa 1999

# %%
nome = "Silvio"
cognome = "Coppa"
anno_di_nascita = 1999
identita = nome + " " + cognome + " " + str(anno_di_nascita)
print(identita)
type(identita)
# Out:
# Silvio Coppa 1999
# str

# %% [markdown]
# Esercizio 8
# Creare una variabile eta_attuale e assegnargli il valore dell'età che hai attualmente, calcolandola in base all'anno corrente. Mandare a schermo eta_attuale

# %%
anno_corrente = input ("Inserisci l'anno corrente: ")
anno_di_nascita = input ("Inserisci il tuo anno di nascita: ")
eta_attuale = int(anno_corrente) - int(anno_di_nascita)
print(eta_attuale)
type(eta_attuale)
# Out:
# Inserisci l'anno corrente: 2025
# Inserisci il tuo anno di nascita: 1999
# 26
# int
